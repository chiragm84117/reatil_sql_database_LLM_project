# %%
from langchain.llms import GooglePalm

# %%
api_key= "AIzaSyBiMTQUmkft3p1fHfE54N3K8mf7OYNWxnE"
llm = GooglePalm(google_api_key=api_key,temperature=0.2)
print(llm("write a poem on friend"))
# Out:
# ---------------------------------------------------------------------------
# DefaultCredentialsError                   Traceback (most recent call last)
# Input In [2], in <cell line: 3>()
#       1 api_key= "AIzaSyBiMTQUmkft3p1fHfE54N3K8mf7OYNWxnE"
#       2 llm = GooglePalm(google_api_key=api_key,temperature=0.2)
# ----> 3 print(llm("write a poem on friend"))
#
# File ~\anaconda3\lib\site-packages\langchain\llms\base.py:825, in BaseLLM.__call__(self, prompt, stop, callbacks, tags, metadata, **kwargs)
#     818 if not isinstance(prompt, str):
#     819     raise ValueError(
#     820         "Argument `prompt` is expected to be a string. Instead found "
#     821         f"{type(prompt)}. If you want to run the LLM on multiple prompts, use "
#     822         "`generate` instead."
#     823     )
#     824 return (
# --> 825     self.generate(
#     826         [prompt],
#     827         stop=stop,
#     828         callbacks=callbacks,
#     829         tags=tags,
# ...
